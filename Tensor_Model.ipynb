# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

DATADIR = "C:/Dataset/PetImages/"

CATEGORIES = ["Dog", "Human"]

for variety in CATEGORIES:  # iterate through for dogs/humans
    path = os.path.join(DATADIR,variety)  #pathway to the files
    for img in os.listdir(path):  #iterates through every image
        convert_array = cv2.imread(os.path.join(path,img) ,cv2.IMREAD_GRAYSCALE)  #converts to a list/array
        plt.imshow(convert_array, cmap="gray")  #turns into a gray image, easier 
        plt.show()  

        break  #makes it so it stops at one picture from each folder

# %%
IMG_SIZE = 70

resize = cv2.resize(resize, (IMG_SIZE, IMG_SIZE))
plt.imshow(resize, cmap = "gray")
plt.show()

# %%
new_data = []
#Need to iterate through everything and make the data set
def training_time():
    for variety in CATEGORIES:
        path = os.path.join(DATADIR,variety)  
        number_convert = CATEGORIES.index(variety) #turns imagines to either 1s or 0s, 1 for dog 0 for human 
        for img in os.listdir(path):  
            try:
                convert_array = cv2.imread(os.path.join(path,img) ,cv2.IMREAD_GRAYSCALE)  
                resize = cv2.resize(resize, (IMG_SIZE, IMG_SIZE))
                new_data.append([resize, number_convert])
            except Exception as p:
                pass 

training_time()

# %%
import random
random.shuffle(new_data)

# %%
for example in new_data[:10]:
    print(example[1])

# %%
neural = []
network = [] 

for extra, features in new_data:
    neural.append(extra)
    network.append(features)

neural = np.array(neural).reshape(-1, IMG_SIZE, IMG_SIZE, 1) #1 is important because of the grayscale
